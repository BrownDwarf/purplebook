# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def cp(T):
    A,B,C,D,E=ShomateCoeffs
    return A + B*(T/1000) + C*(T/1000)**2 + D*(T/1000)**3 + E*(T/1000)**-2

# %%
#N2
N2_coeffs = [931.857, 293.529, -70.576, 5.688, 1.587]
ShomateCoeffs = N2_coeffs
input_T = np.linspace(300,6000,100)
CP = cp(input_T)

# %%
plt.plot(input_T, CP)
plt.xlabel('Temperature (K)')
plt.ylabel('C_p')
# Out:
# Text(0, 0.5, 'C_p')

# %%
#CO2
CO2_coeffs = [568.122, 1254.249, -765.713, 189.645, -3.105]
ShomateCoeffs = CO2_coeffs
input_T = np.linspace(300,1300,100)
CP = cp(input_T)

# %%
plt.plot(input_T, CP)
plt.xlabel('Temperature (K)')
plt.ylabel('C_p')
# Out:
# Text(0, 0.5, 'C_p')

# %%
#NH3
NH3_coeffs = [1176.213, 2927.717, -904.470, 113.009, 11.128]
ShomateCoeffs = NH3_coeffs
input_T = np.linspace(300,1300,100)
CP = cp(input_T)

# %%
plt.plot(input_T, CP)
plt.xlabel('Temperature (K)')
plt.ylabel('C_p')
# Out:
# Text(0, 0.5, 'C_p')

# %%
ShomateCoeffs = N2_coeffs

# %%
n = int((700-300)/0.1)
input_T = 300
Q = 0
for i in range(n):
    CP = cp(input_T)
    Q += CP * 0.1
    input_T += 0.1
print(Q)
# Out:
# 427363.5266559079

# %%
n = int((700-300)/0.1)
input_T = 500
CP = cp(input_T)
Q = CP * 400
print(Q)
# Out:
# 427214.6

# %% [markdown]
# ## The energy is a little bit less if you assume cp to be constant.
